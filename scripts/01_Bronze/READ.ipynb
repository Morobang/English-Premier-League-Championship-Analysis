# %%
import pandas as pd

# Path to your CSV file
file_path = r"C:\Users\Morobang\Documents\GitHub\English Premier League & Championship Analysis\data\England CSV.csv"

# Read the CSV into a DataFrame
df = pd.read_csv(file_path)

# Show the first 5 rows (to verify structure)
print("📄 First 5 Rows:")
display(df.head())

# Filter for HomeTeam = Everton and AwayTeam = Charlton
filtered_df = df[(df['HomeTeam'] == 'Everton') & (df['AwayTeam'] == 'Charlton')]

# Show matching rows
print("\n⚽ Matches where Everton was home and Charlton was away:")
display(filtered_df)
# Out:
# 📄 First 5 Rows:
#          Date   Season      HomeTeam                AwayTeam  FTH Goals  \
# 0  16/01/2025  2024/25  Ipswich Town  Brighton & Hove Albion          0
# 1  16/01/2025  2024/25    Man United             Southampton          3
# 2  15/01/2025  2024/25       Everton             Aston Villa          0
# 3  15/01/2025  2024/25     Leicester          Crystal Palace          0
# 4  15/01/2025  2024/25     Newcastle                  Wolves          3
#
#    FTA Goals FT Result  HTH Goals  HTA Goals HT Result  ... H Fouls  A Fouls  \
# 0          2         A        0.0        1.0         A  ...    13.0     14.0
# 1          1         H        0.0        1.0         A  ...     7.0     10.0
# 2          1         A        0.0        0.0         D  ...    17.0     10.0
# 3          2         A        0.0        0.0         D  ...     7.0      6.0
# 4          0         H        1.0        0.0         H  ...    10.0     13.0
#
# ...

# %%
import pandas as pd

# Step 1: Load the CSV
file_path = r"C:\Users\Morobang\Documents\GitHub\English Premier League & Championship Analysis\data\England CSV.csv"
df = pd.read_csv(file_path)

# Step 2: Show all column names
print("📋 All column names in the dataset:")
for col in df.columns:
    print(f"- '{col}'")

# Step 3: Show first 5 rows to inspect structure
print("\n🧾 Sample data:")
display(df.head())  # Use print(df.head()) if not in Jupyter

# OPTIONAL: Step 4 - Try automatic trimming of column names
df.columns = df.columns.str.strip()  # Removes accidental spaces

# Step 5: Filter records (after verifying column names)
# Replace 'HomeTeam' and 'AwayTeam' with actual column names from above output
try:
    filtered_df = df[(df['HomeTeam'] == 'Everton') & (df['AwayTeam'] == 'Charlton')]
    print("\n⚽ Matches where Everton was home and Charlton was away:")
    display(filtered_df)  # Use print(filtered_df) if not in Jupyter
except KeyError as e:
    print(f"\n❌ Column not found: {e}. Check the exact column names printed above.")
# Out:
# 📋 All column names in the dataset:
# - 'Date'
# - 'Season'
# - 'HomeTeam'
# - 'AwayTeam'
# - 'FTH Goals'
# - 'FTA Goals'
# - 'FT Result'
# - 'HTH Goals'
# - 'HTA Goals'
# - 'HT Result'
# - 'Referee'
# - 'H Shots'
# - 'A Shots'
# - 'H SOT'
# - 'A SOT'
# - 'H Fouls'
# - 'A Fouls'
# - 'H Corners'
# - 'A Corners'
# - 'H Yellow'
# - 'A Yellow'
# - 'H Red'
# - 'A Red'
# - 'Display_Order'
# - 'League'
#
# 🧾 Sample data:
#          Date   Season      HomeTeam                AwayTeam  FTH Goals  \
# 0  16/01/2025  2024/25  Ipswich Town  Brighton & Hove Albion          0
# 1  16/01/2025  2024/25    Man United             Southampton          3
# 2  15/01/2025  2024/25       Everton             Aston Villa          0
# 3  15/01/2025  2024/25     Leicester          Crystal Palace          0
# 4  15/01/2025  2024/25     Newcastle                  Wolves          3
#
#    FTA Goals FT Result  HTH Goals  HTA Goals HT Result  ... H Fouls  A Fouls  \
# ...
